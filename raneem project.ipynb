# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_house_train= pd.read_csv("california_housing_train.csv")
dataset_house_test= pd.read_csv("california_housing_test.csv")

# %%
dataset_house_train.head()

dataset_house_test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
dataset_house_train.tail

dataset_house_test.tail
# Out:
# <bound method NDFrame.tail of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
dataset_house_train.shape
dataset_house_test.shape
# Out:
# (3000, 9)

# %%
dataset_house_train.info
dataset_house_test.info
# Out:
# <bound method DataFrame.info of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
dataset_house_train.describe
dataset_house_test.describe
# Out:
# <bound method NDFrame.describe of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
import matplotlib.pyplot as plt
# we will put our data that we want to show
meadin_income=(6,3,5,6)
house_age=(60,38,59,92)
plt.plot(median_income,house_age)

#titel

plt.title("simple line plot")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# Assuming dataset_house_train is a DataFrame with features and target variable
# Split your dataset into X (features) and y (target)
X = dataset_house_train.drop(columns=['housing_median_age'])  # Replace 'target_column' with your actual target column name
y = dataset_house_train['housing_median_age']

# Instantiate the model
model = LogisticRegression()

# Fit the model to the training data
model.fit(X, y)
# Out:
# C:\Users\1riya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming original DataFrame
# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit and transform the DataFrame with MinMaxScaler
df_normalized = pd.DataFrame(scaler.fit_transform(dataset_house_train), columns=dataset_house_train.columns)

# Print the normalized DataFrame
print(df_normalized)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       1.000000  0.175345            0.274510     0.147885        0.198945
# 1       0.984064  0.197662            0.352941     0.201608        0.294848
# 2       0.975100  0.122210            0.313725     0.018927        0.026847
# 3       0.974104  0.116897            0.254902     0.039515        0.052142
# 4       0.974104  0.109458            0.372549     0.038276        0.050435
# ...          ...       ...                 ...          ...             ...
# 16995   0.008964  0.854410            1.000000     0.058389        0.060987
# 16996   0.007968  0.866100            0.686275     0.061869        0.081782
# 16997   0.004980  0.988310            0.313725     0.070515        0.082247
# 16998   0.004980  0.984060            0.352941     0.070384        0.085506
# 16999   0.000000  0.850159            1.000000     0.047924        0.046400
#
# ...
